# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


def relu(i):
    if i > 0:
        return i
    else:
        return 0



plt.style.use('ggplot')
plt.figure(figsize=(10,5))

input = [i for i in range(-30, 30)]
output = [relu(i) for i in input]
plt.plot(input, output)
plt.show()
